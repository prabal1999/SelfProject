# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("Graduate Admissions.csv")

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
df.dtypes
# Out:
# Serial No.             int64
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %%
plt.plot(df["GRE Score"],df["Chance of Admit"])

# %%
plt.plot(df["TOEFL Score"],df["Chance of Admit"])

# %%
sns.relplot("GRE Score","Chance of Admit",data=df)

# %%
sns.relplot("TOEFL Score","Chance of Admit",data=df,color="orange")

# %%
sns.catplot("Research","GRE Score",data=df,kind="box")

# %%
sns.catplot("Research","TOEFL Score",data=df,kind="box")

# %%
sns.catplot("Research","GRE Score",data=df,kind="violin")

# %%
sns.catplot("Research","TOEFL Score",data=df,kind="violin")

# %%
sns.catplot("Research","TOEFL Score",data=df,kind="swarm")

# %%
import numpy as np

# %%
plt.hist(df["GRE Score"],bins=10,rwidth=0.9)
# Out:
# (array([ 5., 36., 47., 50., 79., 70., 86., 63., 37., 27.]),
#  array([290., 295., 300., 305., 310., 315., 320., 325., 330., 335., 340.]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(df["GRE Score"][df["Research"] == 0],kde=False,label="Non-Researcher")
sns.distplot(df["GRE Score"][df["Research"] == 1],kde=False,color="orange",label="Researcher")
plt.legend()

# %%
sns.distplot(df["TOEFL Score"][df["Research"] == 0],kde=False,label="Non-Researcher")
sns.distplot(df["TOEFL Score"][df["Research"] == 1],kde=False,color="orange",label="Researcher")
plt.legend()

# %%
sns.catplot("University Rating","LOR ",data=df,kind="box")
sns.catplot("University Rating","SOP",data=df,kind="box")

# %%
sns.catplot("University Rating","LOR ",data=df,kind="point",label="LOR")
sns.catplot("University Rating","SOP",data=df,kind="point",color="orange",label="SOP")

# %%
df["Admissions"] = np.where(df["Chance of Admit"] >= 0.70, "Admitted", "Rejected")
df["Admissions"]
# Out:
# 0      Admitted
# 1      Admitted
# 2      Admitted
# 3      Admitted
# 4      Rejected
#          ...
# 495    Admitted
# 496    Admitted
# 497    Admitted
# 498    Admitted
# 499    Admitted
# Name: Admissions, Length: 500, dtype: object

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit Admissions
# 0         1             0.92   Admitted
# 1         1             0.76   Admitted
# 2         1             0.72   Admitted
# 3         1             0.80   Admitted
# 4         0             0.65   Rejected

# %%
df["Admissions"].value_counts()
# Out:
# Admitted    300
# Rejected    200
# Name: Admissions, dtype: int64

# %%
df1 = df[df["Admissions"] == "Admitted"]
df1.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 5           6        330          115                  5  4.5   3.0  9.34
#
#    Research  Chance of Admit Admissions
# 0         1             0.92   Admitted
# 1         1             0.76   Admitted
# 2         1             0.72   Admitted
# 3         1             0.80   Admitted
# 5         1             0.90   Admitted

# %%
sns.catplot("Admissions","SOP",data=df,kind="box")
sns.catplot("Admissions","LOR ",data=df,kind="box")

# %%
df1.SOP.median()
# Out:
# 4.0

# %%
df1["LOR "].median()
# Out:
# 4.0

# %%
df2 = df[df["Chance of Admit"] >= 0.9]
df2.head()
# Out:
#     Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0            1        337          118                  4  4.5   4.5  9.65
# 5            6        330          115                  5  4.5   3.0  9.34
# 22          23        328          116                  5  5.0   5.0  9.50
# 23          24        334          119                  5  5.0   4.5  9.70
# 24          25        336          119                  5  4.0   3.5  9.80
#
#     Research  Chance of Admit Admissions
# 0          1             0.92   Admitted
# 5          1             0.90   Admitted
# 22         1             0.94   Admitted
# 23         1             0.95   Admitted
# 24         1             0.97   Admitted

# %%
sns.relplot("Chance of Admit","GRE Score",data=df2)
sns.relplot("Chance of Admit","TOEFL Score",data=df2,color="green")

# %%
sns.relplot("Chance of Admit","CGPA",data=df,hue="Research")

# %%
sns.relplot("GRE Score","CGPA",data=df,hue="Research")

# %%
sns.catplot("Research","CGPA",data=df,kind="box")

# %%
sns.relplot("LOR ","CGPA",data=df)

# %%
df_threshold = df
df_threshold["Admissions"] = np.where(df["CGPA"] >= 8.5, "Admitted", "Rejected")
df_threshold.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit Admissions
# 0         1             0.92   Admitted
# 1         1             0.76   Admitted
# 2         1             0.72   Rejected
# 3         1             0.80   Admitted
# 4         0             0.65   Rejected

# %%
sns.catplot("Admissions","CGPA",data=df_threshold,kind="box")

# %%
sns.catplot("Admissions","SOP",data=df_threshold,kind="box")
sns.catplot("Admissions","LOR ",data=df_threshold,kind="box")

# %% [markdown]
# # University Rating Analysis

# %%
sns.catplot(y="GRE Score",x="University Rating",data=df,kind="box");sns.catplot(y="TOEFL Score",x="University Rating",data=df,kind="box");
